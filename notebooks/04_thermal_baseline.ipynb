# %% [markdown]
# # Notebook 04: Thermal YOLOv8 Baseline Model Training
#
# Trains the baseline YOLOv8 model exclusively on Infrared Thermal imagery.

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
print('Loaded Thermal YOLOv8 baseline model architecture.')
