# %% [markdown]
# # Notebook 06: Model Evaluation & Comparative Benchmark Suite
#
# Evaluates mAP@50, mAP@50-95, Precision, Recall, and FPS for RGB, Thermal, and Fusion models under Day vs. Night scenarios.

# %%
from src.evaluation.evaluate_models import main as eval_main

eval_main()
