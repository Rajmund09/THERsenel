# %% [markdown]
# # Notebook 03: RGB YOLOv8 Baseline Model Training
#
# Trains the baseline YOLOv8 model exclusively on 3-channel visual RGB imagery.

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
print('Loaded RGB YOLOv8 baseline model architecture.')
