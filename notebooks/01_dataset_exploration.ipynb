# %% [markdown]
# # Notebook 01: FLIR ADAS Dataset Exploration
#
# This notebook inspects the raw FLIR dataset in `data/raw/FLIR/`, counts RGB/Thermal modality distributions, parses annotation formats, and renders visual RGB vs. Thermal sample pairs.

# %%
from pathlib import Path
from src.data.explore_dataset import main as explore_main

# Run dataset exploration
explore_main()
