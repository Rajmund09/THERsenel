# %% [markdown]
# # Notebook 05: RGB + Thermal Spatial Attention Fusion Experiments
#
# Experiments with dual-stream spatial attention feature fusion combining RGB and Thermal feature maps.

# %%
import torch
from src.models.fusion_model import RGBThermalFusionDetector

model = RGBThermalFusionDetector(num_classes=7)
print('Spatial Attention Fusion Model initialized successfully.')
