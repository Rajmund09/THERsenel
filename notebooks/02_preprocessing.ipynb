# %% [markdown]
# # Notebook 02: FLIR Dataset Preprocessing & YOLO Conversion
#
# Converts COCO JSON annotations to normalized YOLO format and organizes `data/processed/train`, `val`, and `test` splits.

# %%
from src.data.preprocessing import main as preprocess_main

# Run preprocessing pipeline
preprocess_main()
